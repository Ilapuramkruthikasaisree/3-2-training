# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilapuramkruthikasaisree/3-2-training/blob/main/day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
set1={56,2,"a",2,78.9}
print(set1)
# Out:
# {56, 'a', 2, 78.9}

# %%
list1=[56,2,"a",78.9]
print(list1)
# Out:
# [56, 2, 'a', 78.9]

# %%
dict1={"key1":1, "key2":2}
print(dict1)
# Out:
# {'key1': 1, 'key2': 2}

# %%
print(dict1.keys())
# Out:
# dict_keys(['key1', 'key2'])

# %%
print(dict1.values())
# Out:
# dict_values([1, 2])

# %%
for i in list1:
  print(i)
# Out:
# 56
# 2
# a
# 78.9

# %%
def add():
  return 23+45
result= add()
print(result)
# Out:
# 68

# %%
birth_year = int(input("Enter your birth year: "))
age = 2025 - birth_year
print("Your age is:", age)
# Out:
# Enter your birth year: 2006
# Your age is: 19

# %%
pip install requests

# %%
import requests

# %%
data = requests.get("https://realpython.com/learning-paths/")
print(data.text)
# Out:
# <!doctype html>
# <html lang="en">
#   <head>
#
#
#     <link href="https://files.realpython.com" rel="preconnect">
#
#     <title>Python Learning Paths – Real Python</title>
#     <meta name="author" content="Real Python">
#     <meta name="description" content="Take your coding skills to the next level with our Python roadmap including learning paths and study plans for beginner, intermediate, and advanced Python developers.">
#     <meta name="keywords" content="">
#
#
#
#
#
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no, viewport-fit=cover">
#
#
#       <link rel="stylesheet" href="/static/realpython.min.fe9eea5e59ad.css">
#
#         <link rel="stylesheet" href="/static/fontawesome.min.3d0609f28af6.css">
#
#       <link rel="stylesheet" href="/static/gfonts/font.5ac42994de49.css">
# ...

# %%
data=requests.get("https://api.github.com/")
print(data.text)
# Out:
# {"current_user_url":"https://api.github.com/user","current_user_authorizations_html_url":"https://github.com/settings/connections/applications{/client_id}","authorizations_url":"https://api.github.com/authorizations","code_search_url":"https://api.github.com/search/code?q={query}{&page,per_page,sort,order}","commit_search_url":"https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}","emails_url":"https://api.github.com/user/emails","emojis_url":"https://api.github.com/emojis","events_url":"https://api.github.com/events","feeds_url":"https://api.github.com/feeds","followers_url":"https://api.github.com/user/followers","following_url":"https://api.github.com/user/following{/target}","gists_url":"https://api.github.com/gists{/gist_id}","hub_url":"https://api.github.com/hub","issue_search_url":"https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}","issues_url":"https://api.github.com/issues","keys_url":"https://api.github.com/user/keys","label_sea
# ...
